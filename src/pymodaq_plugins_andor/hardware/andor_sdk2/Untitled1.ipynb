# %%
import sdk2 as ccd

# %%
camera = ccd.AndorSDK()

# %%
print(camera.init_camera())
# Out:
# Initializing iDus...
# None

# %%
print(camera.GetDetector())
# Out:
# (1024, 256)

# %%
print(camera.GetHSSpeed())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 print(camera.GetHSSpeed())
#
# File C:\repo\pymodaq_plugins_andor\src\pymodaq_plugins_andor\hardware\andor_sdk2\sdk2.py:903, in AndorSDK.GetHSSpeed(self)
#     901 HSSpeed = c_float()
#     902 HSSpeeds = []
# --> 903 for i in range(self.GetNumberHSSpeeds()):
#     904     error = _dll.GetHSSpeed(self._channel, self._outamp, i, byref(HSSpeed))
#     905     if error != 20002:
#
# File C:\repo\pymodaq_plugins_andor\src\pymodaq_plugins_andor\hardware\andor_sdk2\sdk2.py:222, in AndorSDK.GetNumberHSSpeeds(self)
#     212 '''
#     213 Returns the number of HS speeds
#     214
#    (...)    219     (int) : the number of HS speeds
#     220 '''
#     221 noHSSpeeds = c_int()
# --> 222 error = _dll.GetNumberHSSpeeds(self._channel, self._outamp,
# ...
