# %%
import sdk2

# %%
camera = sdk2.AndorSDK()

# %%
camera.init_camera()
# Out:
# Initializing iDus...

# %%
camera.GetDetector()
# Out:
# (1024, 256)

# %%
camera.GetNumberHSSpeeds()
# Out:
# 3

# %%
camera.GetHSSpeed()
# Out:
# [3.0, 1.0, 0.05000000074505806]

# %%
camera.SetHSSpeed(1)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 camera.SetHSSpeed(1)
#
# File C:\repo\pymodaq_plugins_andor\src\pymodaq_plugins_andor\hardware\andor_sdk2\sdk2.py:922, in AndorSDK.SetHSSpeed(self, index)
#     920 error = _dll.SetHSSpeed(index)
#     921 if error != 20002:
# --> 922     raise IOError(ERROR_CODE[error])
#
# OSError: DRV_P1INVALID
